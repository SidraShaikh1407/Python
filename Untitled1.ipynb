# %%
i=3
print(i)
b=2

# %%
s=i+b
print(s)

# %%
a=50
b=5
c=a%b
print(c)

# %%
4+5

# %%
A=23
B=78
SUM= A+B
print('addition of two no :',SUM)

# %%
print("hello world,I am studying Data Science using Python.")
print("Guido Van Rossum invented the Python Programming language.")

# %%
print("menu")
print('1.add')
print('2.sub')
print("3.div")
print('4.mul')
print('5.mod')
print('6.exit')

while(True):
    
    choice=int(input("Enter the choice:"))
    num1 =int(input("Enter num 1:"))
    num2 =int(input("enter num 2:"))
    if choice==1:
        print("result:",num1+num2)
    elif choice==2:
        print("result:",num1-num2)
    elif choice==3:
        print("result:",num1/num2)
    elif choice==4:
        print("result:",num1*num2)
    elif choice==5:
        print("result:",num1%num2)
    elif choice==6:
        break
    else:
        print("enter correct choice.")
