# %%
pip install opendatasets

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: sidrashaikh1475
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database
# ...
# 100%|██████████| 8.91k/8.91k [00:00<00:00, 24.4MB/s]

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd
dataset ="/content/pima-indians-diabetes-database/diabetes.csv"
df=pd.read_csv(dataset)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB
# None

# %% [markdown]
# Lists

# %%
a=[1,2,3,3,3,3,4,5]
b=[6,7,8,9]
print(a.pop(5))
print(a)
del(a)
# Out:
# 3
# [1, 2, 3, 3, 3, 4, 5]

# %%
friends=['Sidra','Bushra','Solkar']
for friend in friends:
  print("Eid Mubarak!",friend,"to you and your family")
# Out:
# Eid Mubarak! Sidra to you and your family
# Eid Mubarak! Bushra to you and your family
# Eid Mubarak! Solkar to you and your family

# %%
friends=['Sidra','Bushra','Solkar']
for i in range(len(friends)):
  friend=friends[i]
  print('Eid Mubarak!',friend)
# Out:
# Eid Mubarak! Sidra
# Eid Mubarak! Bushra
# Eid Mubarak! Solkar

# %%
A=[11,2,3,44,5,6]
B=A
A[1]=22
print(A)
print(B)
# Out:
# [11, 22, 3, 44, 5, 6]
# [11, 22, 3, 44, 5, 6]

# %%
A=[11,2,3,[2,2,3,4,5,6,6],44,5,6]
B=A[:]
A[1]=22
A[3][1]=5000

print(A)
print(B)
# Out:
# [11, 22, 3, [2, 5000, 3, 4, 5, 6, 6], 44, 5, 6]
# [11, 2, 3, [2, 5000, 3, 4, 5, 6, 6], 44, 5, 6]

# %%
import copy
A=[11,2,3,[2,2,3,4,5,6,6],44,5,6]
B=copy.deepcopy(A)
B[3][1]=5000
print(A)
print(B)
# Out:
# [11, 2, 3, [2, 2, 3, 4, 5, 6, 6], 44, 5, 6]
# [11, 2, 3, [2, 5000, 3, 4, 5, 6, 6], 44, 5, 6]

# %%
import copy
A=[11,2,3,[2,2,3,4,5,6,6],44,5,6]
B=copy.copy(A)
B[3][1]=5000
print(A)
print(B)
# Out:
# [11, 2, 3, [2, 5000, 3, 4, 5, 6, 6], 44, 5, 6]
# [11, 2, 3, [2, 5000, 3, 4, 5, 6, 6], 44, 5, 6]

# %%
A='Apple  Banana Cat Fish Goat Dog Elf'
B=list(A.split())
B.sort()
print(B)
# Out:
# ['Apple', 'Banana', 'Cat', 'Dog', 'Elf', 'Fish', 'Goat']

# %%
a=['Rizvi',12,12,23,34,'College']
ls=[]
li=[]
for i in a:
  if isinstance(i,str):
    ls.append(i)
  if isinstance(i,int):
    li.append(i)
print(ls)
print(li)
# Out:
# ['Rizvi', 'College']
# [12, 12, 23, 34]

# %%
a=[1,2,3,4,45]
b=[9,8,76,65,4]
a.extend(b)
print(a)
a.sort()
print(a)
# Out:
# [1, 2, 3, 4, 45, 9, 8, 76, 65, 4]
# [1, 2, 3, 4, 4, 8, 9, 45, 65, 76]

# %%
a=[1,2,3,4,5,6]
even=[]
odd=[]
for i in a:
  if i%2==0:
    even.append(i)
  if i%2!=0:
    odd.append(i)
print(even)
print(odd)
# Out:
# [2, 4, 6]
# [1, 3, 5]

# %%
tup=(2,3,4,5,3,5,5,1)
for i in tup:
  if tup.count(i)>1 :
    print(i,"is repeated")
# Out:
# 3 is repeated
# 5 is repeated
# 3 is repeated
# 5 is repeated
# 5 is repeated

# %%
tup=(2,3,4,5,3,5,5,1)
l=[]
for i in tup:
  if tup.count(i)>1 and l.count(i)==0:
    l.append(i)
    print(i,"is repeated")
# Out:
# 3 is repeated
# 5 is repeated

# %%
set={1,2,3,45,6}
set.remove(45)
print(set)
# Out:
# {1, 2, 3, 6}

# %%
set={1,2,3,45,6}
set.add(55)
print(set)
# Out:
# {1, 2, 3, 6, 55, 45}

# %%
set={1,2,3,45,6}
set.pop()
print(set)
# Out:
# {2, 3, 6, 45}

# %%
set={1,2,3,45,6}
set.clear()
print(set)
# Out:
# set()

# %%
a={1,2,3}
b={2,3,4}
a|b
a.union(b)
# Out:
# {1, 2, 3, 4}

# %%
a={1,2,3}
b={2,3,4}
a&b
a.intersection(b)
# Out:
# {2, 3}

# %%
a={1,2,3}
b={2,3,4}
a-b
a.difference(b)
# Out:
# {1}

# %%
a={1,2,3}
b={2,3,4}
a^b
a.symmetric_difference(b)
# Out:
# {1, 4}
